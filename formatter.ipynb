# %%
input = """
165e53d49dcab412e69a0ae3a2f0291510568855 (survey, calls for integrated approaches)

1dce46450c1a08aa4cc0da964162733b67909fc0 (roadmap for integrating CRL and trust into multi-agent applications)

84ab6f6310257588c94a6eff3b974017b0fa02a3 (tri-level incentive-based frameworks with causal structure for EV + grid)
"""

def format_texts(input_text):
    # Split the input by newlines and strip whitespace
    lines = [line.strip() for line in input_text.strip().split('\n') if line.strip()]
    return lines

formatted_lines = format_texts(input)
print(formatted_lines)
# Out:
# ['165e53d49dcab412e69a0ae3a2f0291510568855 (survey, calls for integrated approaches)', '1dce46450c1a08aa4cc0da964162733b67909fc0 (roadmap for integrating CRL and trust into multi-agent applications)', '84ab6f6310257588c94a6eff3b974017b0fa02a3 (tri-level incentive-based frameworks with causal structure for EV + grid)']
